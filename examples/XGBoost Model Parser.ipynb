# %% [markdown]
# # XGBoost Model Parser
# This notebook shows an example of parsing an xgboost model with pygbmexpl.

# %%
import xgboost as xgb
from sklearn.datasets import load_boston

# %%
import pygbmexpl.xgb.parser as xgb_parser

# %% [markdown]
# # Build example xgboost model

# %% [markdown]
# ## Load data from sklearn

# %%
boston = load_boston()

# %% [markdown]
# ## Create xgboost matrix

# %%
xgb_data = xgb.DMatrix(
    data = boston['data'], 
    label = boston['target'], 
    feature_names = boston['feature_names']
)

# %% [markdown]
# ## Build model

# %%
model = xgb.train(
    params = {
        'silent': 1,
        'max_depth': 3
    }, 
    dtrain = xgb_data, 
    num_boost_round = 10
)

# %% [markdown]
# ## Export model to text and json files

# %%
model.dump_model('dump_raw.txt', with_stats = True)
model.dump_model('dump_raw_no_stats.txt', with_stats = False)

# %%
model.dump_model('dump_raw.json', with_stats = True, dump_format='json')
model.dump_model('dump_raw_no_stats.json', with_stats = False, dump_format='json')

# %% [markdown]
# # Parse model dump

# %% [markdown]
# ## Import text file

# %%
dump_raw1, tree_df1 = xgb_parser.read_dump_text('dump_raw.txt')

# %%
dump_raw2, tree_df2 = xgb_parser.read_dump_text('dump_raw_no_stats.txt')

# %%
dump_raw3, tree_df3 = xgb_parser.read_dump_json('dump_raw.json')

# %%
dump_raw4, tree_df4 = xgb_parser.read_dump_json('dump_raw_no_stats.json')

# %% [markdown]
# ## Raw lines read from files

# %%
dump_raw1[:20]
# Out:
# ['booster[0]:\n',
#  '0:[LSTAT<9.72500038] yes=1,no=2,missing=1,gain=18247.6094,cover=506\n',
#  '\t1:[RM<6.94099998] yes=3,no=4,missing=3,gain=6860.23438,cover=212\n',
#  '\t\t3:[DIS<1.48494995] yes=7,no=8,missing=7,gain=564.898438,cover=142\n',
#  '\t\t\t7:leaf=11.8800001,cover=4\n',
#  '\t\t\t8:leaf=7.20474863,cover=138\n',
#  '\t\t4:[RM<7.43700027] yes=9,no=10,missing=9,gain=713.554688,cover=70\n',
#  '\t\t\t9:leaf=9.67683029,cover=40\n',
#  '\t\t\t10:leaf=12.9474201,cover=30\n',
#  '\t2:[LSTAT<16.0849991] yes=5,no=6,missing=5,gain=2385.59375,cover=294\n',
#  '\t\t5:[B<116.024994] yes=11,no=12,missing=11,gain=118.414062,cover=150\n',
#  '\t\t\t11:leaf=3.54750013,cover=7\n',
#  '\t\t\t12:leaf=5.99104166,cover=143\n',
#  '\t\t6:[NOX<0.603000045] yes=13,no=14,missing=13,gain=639.9375,cover=144\n',
#  '\t\t\t13:leaf=5.06040001,cover=49\n',
#  '\t\t\t14:leaf=3.55718756,cover=95\n',
#  'booster[1]:\n',
#  '0:[RM<6.8375001] yes=1,no=2,missing=1,gain=9723.03125,cover=506\n',
#  '\t1:[LSTAT<14.3999996] yes=3,no=4,missing=3,gain=3428.83594,cover=419\n',
#  '\t\t3:[DIS<1.38485003] yes=7,no=8,missing=7,gain=759.472656,cover=245\n']

# %%
dump_raw2[:20]
# Out:
# ['booster[0]:\n',
#  '0:[LSTAT<9.72500038] yes=1,no=2,missing=1\n',
#  '\t1:[RM<6.94099998] yes=3,no=4,missing=3\n',
#  '\t\t3:[DIS<1.48494995] yes=7,no=8,missing=7\n',
#  '\t\t\t7:leaf=11.8800001\n',
#  '\t\t\t8:leaf=7.20474863\n',
#  '\t\t4:[RM<7.43700027] yes=9,no=10,missing=9\n',
#  '\t\t\t9:leaf=9.67683029\n',
#  '\t\t\t10:leaf=12.9474201\n',
#  '\t2:[LSTAT<16.0849991] yes=5,no=6,missing=5\n',
#  '\t\t5:[B<116.024994] yes=11,no=12,missing=11\n',
#  '\t\t\t11:leaf=3.54750013\n',
#  '\t\t\t12:leaf=5.99104166\n',
#  '\t\t6:[NOX<0.603000045] yes=13,no=14,missing=13\n',
#  '\t\t\t13:leaf=5.06040001\n',
#  '\t\t\t14:leaf=3.55718756\n',
#  'booster[1]:\n',
#  '0:[RM<6.8375001] yes=1,no=2,missing=1\n',
#  '\t1:[LSTAT<14.3999996] yes=3,no=4,missing=3\n',
#  '\t\t3:[DIS<1.38485003] yes=7,no=8,missing=7\n']

# %%
len(dump_raw3)
# Out:
# 10

# %%
dump_raw3[0:1]
# Out:
# [{'nodeid': 0,
#   'depth': 0,
#   'split': 'LSTAT',
#   'split_condition': 9.72500038,
#   'yes': 1,
#   'no': 2,
#   'missing': 1,
#   'gain': 18247.6094,
#   'cover': 506,
#   'children': [{'nodeid': 1,
#     'depth': 1,
#     'split': 'RM',
#     'split_condition': 6.94099998,
#     'yes': 3,
#     'no': 4,
#     'missing': 3,
#     'gain': 6860.23438,
#     'cover': 212,
#     'children': [{'nodeid': 3,
#       'depth': 2,
#       'split': 'DIS',
#       'split_condition': 1.48494995,
#       'yes': 7,
#       'no': 8,
#       'missing': 7,
#       'gain': 564.898438,
#       'cover': 142,
#       'children': [{'nodeid': 7, 'leaf': 11.8800001, 'cover': 4},
#        {'nodeid': 8, 'leaf': 7.20474863, 'cover': 138}]},
#      {'nodeid': 4,
#       'depth': 2,
#       'split': 'RM',
#       'split_condition': 7.43700027,
#       'yes': 9,
#       'no': 10,
#       'missing': 9,
#       'gain': 713.554688,
#       'cover': 70,
#       'children': [{'nodeid': 9, 'leaf': 9.67683029, 'cover': 40},
#        {'nodeid': 10, 'leaf': 12.9474201, 'cover': 30}]}]},
#    {'nodeid': 2,
#     'depth': 1,
#     'split': 'LSTAT',
#     'split_condition': 16.0849991,
#     'yes': 5,
#     'no': 6,
#     'missing': 5,
#     'gain': 2385.59375,
#     'cover': 294,
#     'children': [{'nodeid': 5,
#       'depth': 2,
#       'split': 'B',
#       'split_condition': 116.024994,
#       'yes': 11,
#       'no': 12,
#       'missing': 11,
#       'gain': 118.414062,
#       'cover': 150,
#       'children': [{'nodeid': 11, 'leaf': 3.54750013, 'cover': 7},
#        {'nodeid': 12, 'leaf': 5.99104166, 'cover': 143}]},
#      {'nodeid': 6,
#       'depth': 2,
#       'split': 'NOX',
#       'split_condition': 0.603000045,
#       'yes': 13,
#       'no': 14,
#       'missing': 13,
#       'gain': 639.9375,
#       'cover': 144,
#       'children': [{'nodeid': 13, 'leaf': 5.06040001, 'cover': 49},
#        {'nodeid': 14, 'leaf': 3.55718756, 'cover': 95}]}]}]}]

# %%
len(dump_raw4)
# Out:
# 10

# %%
dump_raw4[0:1]
# Out:
# [{'nodeid': 0,
#   'depth': 0,
#   'split': 'LSTAT',
#   'split_condition': 9.72500038,
#   'yes': 1,
#   'no': 2,
#   'missing': 1,
#   'children': [{'nodeid': 1,
#     'depth': 1,
#     'split': 'RM',
#     'split_condition': 6.94099998,
#     'yes': 3,
#     'no': 4,
#     'missing': 3,
#     'children': [{'nodeid': 3,
#       'depth': 2,
#       'split': 'DIS',
#       'split_condition': 1.48494995,
#       'yes': 7,
#       'no': 8,
#       'missing': 7,
#       'children': [{'nodeid': 7, 'leaf': 11.8800001},
#        {'nodeid': 8, 'leaf': 7.20474863}]},
#      {'nodeid': 4,
#       'depth': 2,
#       'split': 'RM',
#       'split_condition': 7.43700027,
#       'yes': 9,
#       'no': 10,
#       'missing': 9,
#       'children': [{'nodeid': 9, 'leaf': 9.67683029},
#        {'nodeid': 10, 'leaf': 12.9474201}]}]},
#    {'nodeid': 2,
#     'depth': 1,
#     'split': 'LSTAT',
#     'split_condition': 16.0849991,
#     'yes': 5,
#     'no': 6,
#     'missing': 5,
#     'children': [{'nodeid': 5,
#       'depth': 2,
#       'split': 'B',
#       'split_condition': 116.024994,
#       'yes': 11,
#       'no': 12,
#       'missing': 11,
#       'children': [{'nodeid': 11, 'leaf': 3.54750013},
#        {'nodeid': 12, 'leaf': 5.99104166}]},
#      {'nodeid': 6,
#       'depth': 2,
#       'split': 'NOX',
#       'split_condition': 0.603000045,
#       'yes': 13,
#       'no': 14,
#       'missing': 13,
#       'children': [{'nodeid': 13, 'leaf': 5.06040001},
#        {'nodeid': 14, 'leaf': 3.55718756}]}]}]}]

# %% [markdown]
# ## Tree structure

# %%
tree_df1.head(20)
# Out:
#     tree  nodeid  depth   yes    no  missing  split  split_condition  \
# 0      0       0      0   1.0   2.0      1.0  LSTAT         9.725000
# 1      0       1      1   3.0   4.0      3.0     RM         6.941000
# 8      0       2      1   5.0   6.0      5.0  LSTAT        16.084999
# 2      0       3      2   7.0   8.0      7.0    DIS         1.484950
# 5      0       4      2   9.0  10.0      9.0     RM         7.437000
# 9      0       5      2  11.0  12.0     11.0      B       116.024994
# 12     0       6      2  13.0  14.0     13.0    NOX         0.603000
# 3      0       7      3   NaN   NaN      NaN    NaN              NaN
# 4      0       8      3   NaN   NaN      NaN    NaN              NaN
# 6      0       9      3   NaN   NaN      NaN    NaN              NaN
# 7      0      10      3   NaN   NaN      NaN    NaN              NaN
# 10     0      11      3   NaN   NaN      NaN    NaN              NaN
# 11     0      12      3   NaN   NaN      NaN    NaN              NaN
# 13     0      13      3   NaN   NaN      NaN    NaN              NaN
# 14     0      14      3   NaN   NaN      NaN    NaN              NaN
# 15     1       0      0   1.0   2.0      1.0     RM         6.837500
# 16     1       1      1   3.0   4.0      3.0  LSTAT        14.400000
# 23     1       2      1   5.0   6.0      5.0    NOX         0.659000
# 17     1       3      2   7.0   8.0      7.0    DIS         1.384850
# 20     1       4      2   9.0  10.0      9.0   CRIM         6.992370
#
#             gain  cover       leaf
# 0   18247.609400  506.0        NaN
# 1    6860.234380  212.0        NaN
# 8    2385.593750  294.0        NaN
# 2     564.898438  142.0        NaN
# 5     713.554688   70.0        NaN
# 9     118.414062  150.0        NaN
# 12    639.937500  144.0        NaN
# 3            NaN    4.0  11.880000
# 4            NaN  138.0   7.204749
# 6            NaN   40.0   9.676830
# 7            NaN   30.0  12.947420
# 10           NaN    7.0   3.547500
# 11           NaN  143.0   5.991042
# 13           NaN   49.0   5.060400
# 14           NaN   95.0   3.557188
# 15   9723.031250  506.0        NaN
# 16   3428.835940  419.0        NaN
# 23    989.875000   87.0        NaN
# 17    759.472656  245.0        NaN
# 20    766.392578  174.0        NaN

# %%
tree_df2.head(20)
# Out:
#     tree  nodeid  depth   yes    no  missing  split  split_condition  \
# 0      0       0      0   1.0   2.0      1.0  LSTAT         9.725000
# 1      0       1      1   3.0   4.0      3.0     RM         6.941000
# 8      0       2      1   5.0   6.0      5.0  LSTAT        16.084999
# 2      0       3      2   7.0   8.0      7.0    DIS         1.484950
# 5      0       4      2   9.0  10.0      9.0     RM         7.437000
# 9      0       5      2  11.0  12.0     11.0      B       116.024994
# 12     0       6      2  13.0  14.0     13.0    NOX         0.603000
# 3      0       7      3   NaN   NaN      NaN    NaN              NaN
# 4      0       8      3   NaN   NaN      NaN    NaN              NaN
# 6      0       9      3   NaN   NaN      NaN    NaN              NaN
# 7      0      10      3   NaN   NaN      NaN    NaN              NaN
# 10     0      11      3   NaN   NaN      NaN    NaN              NaN
# 11     0      12      3   NaN   NaN      NaN    NaN              NaN
# 13     0      13      3   NaN   NaN      NaN    NaN              NaN
# 14     0      14      3   NaN   NaN      NaN    NaN              NaN
# 15     1       0      0   1.0   2.0      1.0     RM         6.837500
# 16     1       1      1   3.0   4.0      3.0  LSTAT        14.400000
# 23     1       2      1   5.0   6.0      5.0    NOX         0.659000
# 17     1       3      2   7.0   8.0      7.0    DIS         1.384850
# 20     1       4      2   9.0  10.0      9.0   CRIM         6.992370
#
#          leaf
# 0         NaN
# 1         NaN
# 8         NaN
# 2         NaN
# 5         NaN
# 9         NaN
# 12        NaN
# 3   11.880000
# 4    7.204749
# 6    9.676830
# 7   12.947420
# 10   3.547500
# 11   5.991042
# 13   5.060400
# 14   3.557188
# 15        NaN
# 16        NaN
# 23        NaN
# 17        NaN
# 20        NaN

# %%
tree_df3.head(20)
# Out:
#     tree  nodeid  depth   yes    no  missing  split  split_condition  \
# 0      0       0    0.0   1.0   2.0      1.0  LSTAT         9.725000
# 1      0       1    1.0   3.0   4.0      3.0     RM         6.941000
# 2      0       2    1.0   5.0   6.0      5.0  LSTAT        16.084999
# 3      0       3    2.0   7.0   8.0      7.0    DIS         1.484950
# 4      0       4    2.0   9.0  10.0      9.0     RM         7.437000
# 5      0       5    2.0  11.0  12.0     11.0      B       116.024994
# 6      0       6    2.0  13.0  14.0     13.0    NOX         0.603000
# 7      0       7    NaN   NaN   NaN      NaN    NaN              NaN
# 8      0       8    NaN   NaN   NaN      NaN    NaN              NaN
# 9      0       9    NaN   NaN   NaN      NaN    NaN              NaN
# 10     0      10    NaN   NaN   NaN      NaN    NaN              NaN
# 11     0      11    NaN   NaN   NaN      NaN    NaN              NaN
# 12     0      12    NaN   NaN   NaN      NaN    NaN              NaN
# 13     0      13    NaN   NaN   NaN      NaN    NaN              NaN
# 14     0      14    NaN   NaN   NaN      NaN    NaN              NaN
# 0      1       0    0.0   1.0   2.0      1.0     RM         6.837500
# 1      1       1    1.0   3.0   4.0      3.0  LSTAT        14.400000
# 2      1       2    1.0   5.0   6.0      5.0    NOX         0.659000
# 3      1       3    2.0   7.0   8.0      7.0    DIS         1.384850
# 4      1       4    2.0   9.0  10.0      9.0   CRIM         6.992370
#
#             gain  cover       leaf
# 0   18247.609400    506        NaN
# 1    6860.234380    212        NaN
# 2    2385.593750    294        NaN
# 3     564.898438    142        NaN
# 4     713.554688     70        NaN
# 5     118.414062    150        NaN
# 6     639.937500    144        NaN
# 7            NaN      4  11.880000
# 8            NaN    138   7.204749
# 9            NaN     40   9.676830
# 10           NaN     30  12.947420
# 11           NaN      7   3.547500
# 12           NaN    143   5.991042
# 13           NaN     49   5.060400
# 14           NaN     95   3.557188
# 0    9723.031250    506        NaN
# 1    3428.835940    419        NaN
# 2     989.875000     87        NaN
# 3     759.472656    245        NaN
# 4     766.392578    174        NaN

# %%
tree_df4.head(20)
# Out:
#     tree  nodeid  depth   yes    no  missing  split  split_condition  \
# 0      0       0    0.0   1.0   2.0      1.0  LSTAT         9.725000
# 1      0       1    1.0   3.0   4.0      3.0     RM         6.941000
# 2      0       2    1.0   5.0   6.0      5.0  LSTAT        16.084999
# 3      0       3    2.0   7.0   8.0      7.0    DIS         1.484950
# 4      0       4    2.0   9.0  10.0      9.0     RM         7.437000
# 5      0       5    2.0  11.0  12.0     11.0      B       116.024994
# 6      0       6    2.0  13.0  14.0     13.0    NOX         0.603000
# 7      0       7    NaN   NaN   NaN      NaN    NaN              NaN
# 8      0       8    NaN   NaN   NaN      NaN    NaN              NaN
# 9      0       9    NaN   NaN   NaN      NaN    NaN              NaN
# 10     0      10    NaN   NaN   NaN      NaN    NaN              NaN
# 11     0      11    NaN   NaN   NaN      NaN    NaN              NaN
# 12     0      12    NaN   NaN   NaN      NaN    NaN              NaN
# 13     0      13    NaN   NaN   NaN      NaN    NaN              NaN
# 14     0      14    NaN   NaN   NaN      NaN    NaN              NaN
# 0      1       0    0.0   1.0   2.0      1.0     RM         6.837500
# 1      1       1    1.0   3.0   4.0      3.0  LSTAT        14.400000
# 2      1       2    1.0   5.0   6.0      5.0    NOX         0.659000
# 3      1       3    2.0   7.0   8.0      7.0    DIS         1.384850
# 4      1       4    2.0   9.0  10.0      9.0   CRIM         6.992370
#
#          leaf
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7   11.880000
# 8    7.204749
# 9    9.676830
# 10  12.947420
# 11   3.547500
# 12   5.991042
# 13   5.060400
# 14   3.557188
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# ## Other useful tree information

# %% [markdown]
# Total number of nodes in all trees

# %%
tree_df3.shape[0]
# Out:
# 144

# %% [markdown]
# Number of nodes per tree

# %%
tree_df3.groupby('tree').size()
# Out:
# tree
# 0    15
# 1    13
# 2    13
# 3    15
# 4    15
# 5    15
# 6    15
# 7    15
# 8    13
# 9    15
# dtype: int64

# %% [markdown]
# Number of terminal nodes per tree

# %%
tree_df3.loc[tree_df3['split'].isnull()].groupby('tree').size()
# Out:
# tree
# 0    8
# 1    7
# 2    7
# 3    8
# 4    8
# 5    8
# 6    8
# 7    8
# 8    7
# 9    8
# dtype: int64

# %% [markdown]
# # Get tree node predictions

# %%
tree_df = xgb_parser.extract_model_predictions(model)

# %%
tree_df.head(20)
# Out:
#     index  tree  nodeid  depth   yes    no  missing  split  split_condition  \
# 0       0     0       0      0   1.0   2.0      1.0  LSTAT         9.725000
# 1       1     0       1      1   3.0   4.0      3.0     RM         6.941000
# 2       8     0       2      1   5.0   6.0      5.0  LSTAT        16.084999
# 3       2     0       3      2   7.0   8.0      7.0    DIS         1.484950
# 4       5     0       4      2   9.0  10.0      9.0     RM         7.437000
# 5       9     0       5      2  11.0  12.0     11.0      B       116.024994
# 6      12     0       6      2  13.0  14.0     13.0    NOX         0.603000
# 7       3     0       7      3   NaN   NaN      NaN    NaN              NaN
# 8       4     0       8      3   NaN   NaN      NaN    NaN              NaN
# 9       6     0       9      3   NaN   NaN      NaN    NaN              NaN
# 10      7     0      10      3   NaN   NaN      NaN    NaN              NaN
# 11     10     0      11      3   NaN   NaN      NaN    NaN              NaN
# 12     11     0      12      3   NaN   NaN      NaN    NaN              NaN
# 13     13     0      13      3   NaN   NaN      NaN    NaN              NaN
# 14     14     0      14      3   NaN   NaN      NaN    NaN              NaN
# 15     15     1       0      0   1.0   2.0      1.0     RM         6.837500
# 16     16     1       1      1   3.0   4.0      3.0  LSTAT        14.400000
# 17     23     1       2      1   5.0   6.0      5.0    NOX         0.659000
# 18     17     1       3      2   7.0   8.0      7.0    DIS         1.384850
# 19     20     1       4      2   9.0  10.0      9.0   CRIM         6.992370
#
#             gain  cover       leaf     weight node_type      H            G
# 0   18247.609400  506.0        NaN   6.491532  internal  506.0 -3284.715003
# 1    6860.234380  212.0        NaN   8.572034  internal  212.0 -1817.271126
# 2    2385.593750  294.0        NaN   4.991306  internal  294.0 -1467.443877
# 3     564.898438  142.0        NaN   7.336446  internal  142.0 -1041.775311
# 4     713.554688   70.0        NaN  11.078512  internal   70.0  -775.495815
# 5     118.414062  150.0        NaN   5.877010  internal  150.0  -881.551458
# 6     639.937500  144.0        NaN   4.068697  internal  144.0  -585.892419
# 7            NaN    4.0  11.880000  11.880000      leaf    4.0   -47.520000
# 8            NaN  138.0   7.204749   7.204749      leaf  138.0  -994.255311
# 9            NaN   40.0   9.676830   9.676830      leaf   40.0  -387.073212
# 10           NaN   30.0  12.947420  12.947420      leaf   30.0  -388.422603
# 11           NaN    7.0   3.547500   3.547500      leaf    7.0   -24.832501
# 12           NaN  143.0   5.991042   5.991042      leaf  143.0  -856.718957
# 13           NaN   49.0   5.060400   5.060400      leaf   49.0  -247.959600
# 14           NaN   95.0   3.557188   3.557188      leaf   95.0  -337.932818
# 15   9723.031250  506.0        NaN   4.588587  internal  506.0 -2321.825084
# 16   3428.835940  419.0        NaN   4.000248  internal  419.0 -1676.104063
# 17    989.875000   87.0        NaN   7.422081  internal   87.0  -645.721021
# 18    759.472656  245.0        NaN   4.732571  internal  245.0 -1159.479809
# 19    766.392578  174.0        NaN   2.969105  internal  174.0  -516.624254
